# %% [markdown]
# <a href="https://colab.research.google.com/github/HugoFabian128/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-utiliza-recepcionista/blob/main/UIII_Act_9_Proyecto_de_simulaci%C3%B3n_de_inteligencia_artificial_Hugo_recepcionista_0040.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #### Hugo Fabian NL  = 17 Fecha 25/may/26
# #### recepcionista

# %%
# Lista vacía para guardar citas
recepcionista = []

print("===================================")
print(" 🤖 RECEPCIONISTA INTELIGENTE ")
print("===================================")

nombre = input("Ingresa tu nombre: ")
print("Hola", nombre, "😊 Bienvenido/a")

opcion = 0

while opcion != 5:
    print("\n----- MENÚ -----")
    print("1. Ver citas")
    print("2. Agendar cita")
    print("3. Cancelar última cita")
    print("4. Información")
    print("5. Salir")

    opcion = int(input("Elige una opción: "))

    if opcion == 1:
        print("\n📋 LISTA DE CITAS:")
        if not citas:
            print("No hay citas registradas.")
        else:
            print(citas)

    elif opcion == 2:
        dia = input("Ingresa el día de tu cita: ")
        citas.append(dia)
        print("✔ Cita agregada correctamente.")

    elif opcion == 3:
        if not citas:
            print("❌ No hay citas para cancelar.")
        else:
            eliminada = citas.pop()
            print("🗑 Se eliminó la cita del día:", eliminada)

    elif opcion == 4:
        print("\nℹ Horario: Lunes a Viernes de 8am a 3pm")

    elif opcion == 5:
        print("\n👋 Gracias por usar la recepción IA.")

    else:
        print("\n⚠ Opción no válida.")
# Out:
# ...
#  🤖 RECEPCIONISTA INTELIGENTE
# ...
# Ingresa tu nombre: hugo
# Hola hugo 😊 Bienvenido/a
#
# ----- MENÚ -----
# 1. Ver citas
# 2. Agendar cita
# 3. Cancelar última cita
# 4. Información
# 5. Salir
# Elige una opción: 1
#
# 📋 LISTA DE CITAS:
# No hay citas registradas.
#
# ----- MENÚ -----
# 1. Ver citas
# 2. Agendar cita
# 3. Cancelar última cita
# 4. Información
# 5. Salir
# Elige una opción: 2
# Ingresa el día de tu cita: 2
# ✔ Cita agregada correctamente.
#
# ----- MENÚ -----
# 1. Ver citas
# 2. Agendar cita
# 3. Cancelar última cita
# 4. Información
# 5. Salir
# Elige una opción: 3
# 🗑 Se eliminó la cita del día: 2
#
# ----- MENÚ -----
# 1. Ver citas
# 2. Agendar cita
# 3. Cancelar última cita
# 4. Información
# 5. Salir
# Elige una opción: 4
#
# ℹ Horario: Lunes a Viernes de 8am a 3pm
#
# ----- MENÚ -----
# 1. Ver citas
# 2. Agendar cita
# 3. Cancelar última cita
# 4. Información
# 5. Salir
# Elige una opción: 5
#
# 👋 Gracias por usar la recepción IA.

# %% [markdown]
# ![texto del vínculo](https://raw.githubusercontent.com/HugoFabian128/UIII-Act-9-Proyecto-de-simulaci-n-de-inteligencia-artificial-utiliza-recepcionista/refs/heads/main/info243645.png)
